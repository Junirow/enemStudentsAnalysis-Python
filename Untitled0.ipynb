# %% [markdown]
# <a href="https://colab.research.google.com/github/Junirow/RepositoryO/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

font = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

data = pd.read_csv(font)
data.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
data[['TP_SEXO', 'NU_NOTA_REDACAO', 'SG_UF_NASCIMENTO']]
# Out:
#        TP_SEXO  NU_NOTA_REDACAO SG_UF_NASCIMENTO
# 0            M            420.0               PA
# 1            M            400.0               PA
# 2            F            560.0               PA
# 3            F            500.0               PA
# 4            F            780.0               PA
# ...        ...              ...              ...
# 127375       F            740.0               MG
# 127376       M            520.0               BA
# 127377       F            440.0               BA
# 127378       F            620.0               BA
# 127379       M            480.0               MG
#
# [127380 rows x 3 columns]

# %%
data['SG_UF_RESIDENCIA']
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
data['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
len(data['SG_UF_RESIDENCIA'].unique())
# Out:
# 27

# %%
data['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
data['NU_IDADE'].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
data[['NU_IDADE', 'NU_NOTA_REDACAO']].value_counts().sort_index()
# Out:
# NU_IDADE  NU_NOTA_REDACAO
# 13        500.0               1
#           920.0               1
# 14        0.0                10
#           280.0               1
#           300.0               2
#                              ..
# 72        460.0               1
# 73        320.0               1
#           560.0               1
# 75        280.0               1
#           620.0               1
# Length: 1793, dtype: int64

# %%
data[['NU_IDADE', 'NO_MUNICIPIO_RESIDENCIA']].value_counts().sort_index()
# Out:
# NU_IDADE  NO_MUNICIPIO_RESIDENCIA
# 13        Atibaia                    1
#           Jacobina                   1
#           Macapá                     1
#           Rondonópolis               1
# 14        Adustina                   1
#                                     ..
# 75        Salvador                   1
#           Vitória da Conquista       1
# 76        Salvador                   1
# 77        Niterói                    1
# 82        Niterói                    1
# Length: 33400, dtype: int64

# %%
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 127375    0
# 127376    0
# 127377    0
# 127378    0
# 127379    0
# Name: IN_TREINEIRO, Length: 127380, dtype: int64

# %%
data['NU_IDADE'].hist()

# %%
import pylab as pl
data['NU_IDADE'].hist(bins=20, figsize=(10,8))
pl.suptitle('Inscritos por idade')
# Out:
# Text(0.5, 0.98, 'Inscritos por idade')

# %%
data.query('IN_TREINEIRO == 1')
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# 12      190001005076    2019                  1506138  ...    A     A    B
# 14      190001005081    2019                  1506807  ...    A     A    B
# 16      190001005202    2019                  1502301  ...    A     A    A
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127328  190006117441    2019                  3126752  ...    A     A    B
# 127340  190006117776    2019                  4305108  ...    A     C    B
# 127349  190006118483    2019                  2511301  ...    A     A    A
# 127350  190006118551    2019                  2611606  ...    B     B    B
# 127352  190006118561    2019                  2600807  ...    A     A    B
#
# [15401 rows x 136 columns]

# %%
data.query('NU_IDADE < 16')
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 12      190001005076    2019                  1506138  ...    A     A    B
# 238     190001013585    2019                  1500800  ...    A     B    A
# 310     190001016485    2019                  1501402  ...    A     A    A
# 316     190001016728    2019                  1504802  ...    A     A    A
# 347     190001017996    2019                  1501402  ...    A     B    B
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127008  190006099362    2019                  3109105  ...    A     A    B
# 127086  190006103363    2019                  2910800  ...    A     B    B
# 127240  190006112478    2019                  2210631  ...    A     A    B
# 127318  190006117130    2019                  2507507  ...    A     A    B
# 127349  190006118483    2019                  2511301  ...    A     A    A
#
# [2154 rows x 136 columns]

# %%
data.query('IN_TREINEIRO==1')['NU_IDADE'].value_counts().sort_index
# Out:
# <bound method Series.sort_index of 16    7142
# 17    4901
# 15    1927
# 18     858
# 19     228
# 20      83
# 14      64
# 21      44
# 22      30
# 23      21
# 24      13
# 26      13
# 29      10
# 27       9
# 25       8
# 28       6
# 38       4
# 40       4
# 31       4
# 30       4
# 42       4
# 34       3
# 36       2
# 39       2
# 32       2
# 46       2
# 44       2
# 35       2
# 45       1
# 41       1
# 33       1
# 62       1
# 48       1
# 51       1
# 37       1
# 47       1
# 55       1
# Name: NU_IDADE, dtype: int64>

# %%
data.query('IN_TREINEIRO==1')['NU_IDADE'].hist(bins=20, figsize=(10,8))

# %%
data.query('IN_TREINEIRO!=1')['NU_IDADE'].hist(bins=20, figsize=(10,8))

# %%
data.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
data['NU_NOTA_REDACAO'].hist(bins=20, figsize=(8,6))

# %%
data['NU_NOTA_CN'].hist(bins=20, figsize=(8,6))

# %%
data['NU_NOTA_REDACAO'].mean()
# Out:
# 571.5700253970197

# %%
data['NU_NOTA_REDACAO'].std()
# Out:
# 188.07645455749753

# %%
exam=['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT', 'NU_NOTA_LC', 'NU_NOTA_REDACAO']

data[exam].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000
